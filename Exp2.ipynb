# %%
#TASK 2   STEMMING:
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('sentences')
# Out:
# 'sentenc'

# %%
#LAB 29.05.10

# %%
import nltk
from nltk.stem import LancasterStemmer
stemmerLan =LancasterStemmer()
stemmerLan.stem('sentences')
# Out:
# 'sent'

# %%
import nltk
from nltk.stem import RegexpStemmer
stemmerregexp=RegexpStemmer('charm')
stemmerregexp.stem('charming')
# Out:
# 'ing'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer=SnowballStemmer('french')
frenchstemmer.stem('manges')
# Out:
# 'mang'

# %%
#TASK 3: STEMMING PARAGRAPHS
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
example = "Following is the list of sentences tokenized from the sample review"
example = [stemmer.stem(token) for token in example.split(" ")]
print (" ".join(example))
# Out:
# follow is the list of sentenc token from the sampl review

# %%
# TASK 4: LEMMATIZER
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("mice"))
print(lemmatizer.lemmatize("rocks"))

print(lemmatizer.lemmatize("better", pos = 'a')) # given the part-of-speech, better lemmatizes to good

print(lemmatizer.lemmatize("Am"))   # This error is fixed when the PArt of Speech is given

print(lemmatizer.lemmatize("am", pos = 'v'))
# Out:
# cactus
# mouse
# rock
# good
# Am
# be

# %%
# TASK 5: CHINESE SEGMENTATION USING JIEBA

import jieba
seg = jieba.cut("把句子中所有的可以成词的词语都扫描出来", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\pkdut\AppData\Local\Temp\jieba.cache
# Loading model cost 1.839 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
# TASK 6: BASIC TEXT PROCESSING PIPELINE

import nltk
sent = "Become an expert in NLP"
words = nltk.word_tokenize(sent)
print(words)

texts = ["""Following is the list of sentences tokenized from the sample review"""]
# Out:
# ['Become', 'an', 'expert', 'in', 'NLP']

# %%
for text in texts:
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# ['Following', 'is', 'the', 'list', 'of', 'sentences', 'tokenized', 'from', 'the', 'sample', 'review']
# [('Following', 'VBG'), ('is', 'VBZ'), ('the', 'DT'), ('list', 'NN'), ('of', 'IN'), ('sentences', 'NNS'), ('tokenized', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('sample', 'NN'), ('review', 'NN')]

# %%
#Homework3 snowball stemming

# %%
from nltk.stem import SnowballStemmer
print(" ".join(SnowballStemmer.languages))
# Out:
# arabic danish dutch english finnish french german hungarian italian norwegian porter portuguese romanian russian spanish swedish

# %%
#snowball
import nltk
sno = nltk.stem.SnowballStemmer('english')
sno.stem('grows')
'grow'
# Out:
# 'grow'

# %%
sno.stem('leaves')
# Out:
# 'leav'

# %%
sno.stem('fairly')
# Out:
# 'fair'

# %%
import snowballstemmer
stemmer = snowballstemmer.stemmer('english');
print(stemmer.stemWords("We are the world".split()));
# Out:
# ['We', 'are', 'the', 'world']

# %%
stemmer = SnowballStemmer("english")
print(stemmer.stem("running"))
# Out:
# run

# %%
stemmer2 = SnowballStemmer("english", ignore_stopwords=True)
print(stemmer.stem("having"))
# Out:
# have

# %%
print(stemmer2.stem("having"))
# Out:
# having

# %%
print(SnowballStemmer("english").stem("generously"))
# Out:
# generous

# %%
print(SnowballStemmer("porter").stem("generously"))
# Out:
# gener

# %%
from nltk.stem import SnowballStemmer
 
st = SnowballStemmer("english")
text = ['Where did he learn to dance like that?',
        'His eyes were dancing with humor.',
        'She shook her head and danced away',
        'Alex was an excellent dancer.']
 
output = []
for sentence in text:
    output.append(" ".join([st.stem(i) for i in sentence.split()]))
 
for item in output:
    print(item)
 
print("-" * 50)
print(st.stem('jumping'), st.stem('jumps'), st.stem('jumped'))
# Out:
# where did he learn to danc like that?
# his eye were danc with humor.
# she shook her head and danc away
# alex was an excel dancer.
# --------------------------------------------------
# jump jump jump

# %%
import nltk 
print('NLTK Version: %s' % (nltk.__version__))

snowball_stemmer = nltk.stem.SnowballStemmer('english')


article = 'In linguistic morphology and information retrieval, stemming is the process of \
reducing inflected (or sometimes derived) words to their word stem, base or root \
form—generally a written word form. The stem need not be identical to the morphological \
root of the word; it is usually sufficient that related words map to the same stem, even \
if this stem is not in itself a valid root.'
# Out:
# NLTK Version: 3.4.5

# %%
tokens = nltk.word_tokenize(article)
print('Original Article: %s' % (article))
print()

for token in tokens:
    stemmed_token = snowball_stemmer.stem(token)
    
    if token != stemmed_token:
        print('Original : %s, New: %s' % (token, stemmed_token))
# Out:
# Original Article: In linguistic morphology and information retrieval, stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form—generally a written word form. The stem need not be identical to the morphological root of the word; it is usually sufficient that related words map to the same stem, even if this stem is not in itself a valid root.
#
# Original : In, New: in
# Original : linguistic, New: linguist
# Original : morphology, New: morpholog
# Original : information, New: inform
# Original : retrieval, New: retriev
# Original : stemming, New: stem
# Original : reducing, New: reduc
# Original : inflected, New: inflect
# Original : sometimes, New: sometim
# Original : derived, New: deriv
# Original : words, New: word
# Original : form—generally, New: form—gener
# Original : The, New: the
# Original : identical, New: ident
# Original : morphological, New: morpholog
# Original : usually, New: usual
# ...

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer(language='english')

tokens = ['compute', 'computer', 'computed', 'computing']

for token in tokens:
    print(token + ' --> ' + stemmer.stem(token))
# Out:
# compute --> comput
# computer --> comput
# computed --> comput
# computing --> comput

# %%
#HOMEWORK 4 TOKENIZATION,STEMMING AND TAGGING USING A CORPUS DATA

# %%
#IMPORT
import nltk 
from nltk.stem import PorterStemmer 
from nltk.corpus import brown

# %%
#FIELDS IN BROWN CORPUS
brown.fileids()[:5]
# Out:
# ['ca01', 'ca02', 'ca03', 'ca04', 'ca05']

# %%
#length of corpus 
len(brown.fileids())
# Out:
# 500

# %%
#we are taking reviews from brown corpus 
browntext = brown.words('ca01')

# %%
#length of our text file 
len(browntext)
# Out:
# 2242

# %%
print(browntext)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
#frequency distribution 
f_dist = nltk.FreqDist(w.lower() for w in browntext)

# %%
f_dist
# Out:
# FreqDist({'the': 155, '.': 88, ',': 87, 'of': 65, 'to': 55, 'a': 54, 'in': 40, 'and': 40, '``': 34, "''": 33, ...})

# %%
#conditional frequency distribution 
from nltk.probability import ConditionalFreqDist 
fcd=ConditionalFreqDist((len(word),word) for word in browntext) 
fcd[2]
# Out:
# FreqDist({'of': 65, 'to': 55, 'in': 39, '``': 34, "''": 33, 'be': 21, 'it': 13, 'is': 12, 'as': 12, 'by': 10, ...})

# %%
fcd[3]
# Out:
# FreqDist({'the': 127, 'and': 40, 'The': 28, 'for': 22, 'was': 18, 'has': 10, 'his': 10, 'new': 6, 'not': 6, 'who': 6, ...})

# %%
#1)converting list to string and tokenizing 
from nltk.tokenize import sent_tokenize
#converting list to single string str1
str=" ".join(browntext)
tokens=sent_tokenize(str)
print(tokens)
# Out:
# ["The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place .", "The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted .", "The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .", "`` Only a relative handful of such reports was received '' , the jury said , `` considering the widespread interest in the election , the number of voters and the size of this city '' .", "The jury said it did find that many of Georgia's registration and election laws `` are outmoded or inadequate and often ambiguous '' .", "It recommended that Fulton legislator
# ...

# %%
#POS tagging
str1 = str

tokenst=nltk.word_tokenize(str1)
print(tokenst)

tagg = nltk.pos_tag(tokenst)

print(tagg)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', 'Atlanta', "'s", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', '``', 'that', 'any', 'irregularities', 'took', 'place', '.', 'The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', '``', 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.', 'The', 'September-October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', '``', 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.', '``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'repo
# ...

# %%
#Stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print("Orignal Sentence:",str1)
print("\n")

str1 = [stemmer.stem(token) for token in str1.split(" ")]
print("Stemmed Sentence:")
print(" ".join(str1))
# Out:
# Orignal Sentence: The Fulton County Grand Jury said Friday an investigation of Atlanta's recent primary election produced `` no evidence '' that any irregularities took place . The jury further said in term-end presentments that the City Executive Committee , which had over-all charge of the election , `` deserves the praise and thanks of the City of Atlanta '' for the manner in which the election was conducted . The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. . `` Only a relative handful of such reports was received '' , the jury said , `` considering the widespread interest in the election , the number of voters and the size of this city '' . The jury said it did find that many of Georgia's registration and election laws `` are outmoded or inadequate and often ambiguous '' . It recommended that Fulton legislato
# ...

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.461

# %%
# Tool names for positive and negative
#TEXTBLOB
#Jensen
# CMU Sphinx

# %%
# do plagarism task using vectorization

# %%
#IMPORT
import nltk 
from nltk.stem import PorterStemmer 
from nltk.corpus import indian

# %%
#FIELDS IN INDIAN CORPUS
indian.fileids()[:10]
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'telugu.pos']

# %%
#we are taking reviews from brown corpus 
text_b = indian.words('bangla.pos')

# %%
#length of our text file 
len(text_b)
# Out:
# 10281

# %%
print(text_b)
# Out:
# ['মহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', ...]

# %%
#frequency distribution 
freqdist = nltk.FreqDist(w.lower() for w in text_b)

freqdist
# Out:
# FreqDist({'৷': 840, ',': 240, 'না': 122, 'হয়': 110, 'করে': 88, 'এই': 62, 'ও': 57, "'": 54, '-': 54, 'তার': 52, ...})

# %%
#conditional frequency distribution 
from nltk.probability import ConditionalFreqDist 
fcd=ConditionalFreqDist((len(word),word) for word in text_b)

# %%
fcd[2]
# Out:
# FreqDist({'না': 122, 'হয়': 110, 'এই': 62, 'আর': 40, 'যে': 40, 'বা': 38, 'সে': 38, 'এক': 36, 'কি': 36, 'নয়': 31, ...})

# %%
fcd[3]
# Out:
# FreqDist({'করে': 88, 'তার': 52, 'কোন': 44, 'করা': 38, 'হয়ে': 37, 'নকল': 36, 'এবং': 35, 'যায়': 31, 'সেই': 30, 'কথা': 30, ...})

# %%
#1)converting list to string and tokenizing 
from nltk.tokenize import sent_tokenize
#converting list to single string str1
string=" ".join(text_b)
tokenized=sent_tokenize(string)
print(tokenized)
# Out:
# ["মহিষের সন্তান : তোড়া উপজাতি ৷ বাসস্থান-ঘরগৃহস্থালি তোড়া ভাষায় গ্রামকেও বলে ` মোদ ' ৷ মোদের আয়তন খুব বড়ো নয় ৷ প্রতি মোদে আছে কিছু কুঁড়েঘর , সাধারণ মহিষশালা ৷ আর গ্রামের বাইরে থাকে ডেয়ারি-মন্দির ৷ আয়তনের তারতম্য অনুসারে গ্রামগুলি দু রকমের : এতূডমোদ ( বড়ো গ্রাম ) ওকিনমোদ ( ছোট গ্রাম ) ৷ কোন কোন গ্রামের আবার ধর্মীয় বা_C\ufeffমহিষের সন্তান : তোড়া উপজাতি ৷ িকে বলে ` সোতি-মোদ ' ৷ কুঁড়েঘরগুলির আকার বাংলার বা ভারতের অন্য অঞ্চলের প্রচলিত কুঁড়ে ঘর নয় ৷ এগুলি দেখতে শোয়ানো পিপের মতো ৷ এক দিকের বাঁশের কাঠামো খিলানের মতো বেঁকে গিয়ে অন্যদিকের মাটিতে মিশেছে ৷ সেগুলি বেত জাতীয় লতা দিয়ে পরস্পর বাঁধা ৷ ঘরগুলি লম্বায় 18 ফুট , চওড়ায় 9 ফুট আর উচ্চতায় 10 ফুটের মতো ৷ উপরের ঢালু চাল ঘাস-পাতা দিয়ে মোটা করে ছাওয়া ৷ যাতে বৃষ্টির জল ভেতরে ঢুকতে না পারে ৷ কুঁড়ের সামনের দিকে একটি মাত্র দরজা , আর কোথাও কোন রকমের জানলা বা ঘুলঘুলি নেই ৷ ঘরের ভেতরে ডানদিকের মেঝে কিছুটা উঁচু করে তোলা - সেটি তাদের শোবার জায়গা ৷ বাঁদিকে অগ্নিকুণ্ড - তার পাশে রান্না করার জায়গা ৷ সেখানেও মেঝে কিছুটা উঁচু - রান্নার সরঞ্জাম ও বাসনকোসন থাকে 
# ...

# %%
#POS tagging
str1 = string

tokenizeds=nltk.word_tokenize(str1)
print(tokenizeds)

tagged = nltk.pos_tag(tokenizeds)
print(tagged)
# Out:
# ['মহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', 'বাসস্থান-ঘরগৃহস্থালি', 'তোড়া', 'ভাষায়', 'গ্রামকেও', 'বলে', '`', 'মোদ', "'", '৷', 'মোদের', 'আয়তন', 'খুব', 'বড়ো', 'নয়', '৷', 'প্রতি', 'মোদে', 'আছে', 'কিছু', 'কুঁড়েঘর', ',', 'সাধারণ', 'মহিষশালা', '৷', 'আর', 'গ্রামের', 'বাইরে', 'থাকে', 'ডেয়ারি-মন্দির', '৷', 'আয়তনের', 'তারতম্য', 'অনুসারে', 'গ্রামগুলি', 'দু', 'রকমের', ':', 'এতূডমোদ', '(', 'বড়ো', 'গ্রাম', ')', 'ওকিনমোদ', '(', 'ছোট', 'গ্রাম', ')', '৷', 'কোন', 'কোন', 'গ্রামের', 'আবার', 'ধর্মীয়', 'বা_C\ufeffমহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', 'িকে', 'বলে', '`', 'সোতি-মোদ', "'", '৷', 'কুঁড়েঘরগুলির', 'আকার', 'বাংলার', 'বা', 'ভারতের', 'অন্য', 'অঞ্চলের', 'প্রচলিত', 'কুঁড়ে', 'ঘর', 'নয়', '৷', 'এগুলি', 'দেখতে', 'শোয়ানো', 'পিপের', 'মতো', '৷', 'এক', 'দিকের', 'বাঁশের', 'কাঠামো', 'খিলানের', 'মতো', 'বেঁকে', 'গিয়ে', 'অন্যদিকের', 'মাটিতে', 'মিশেছে', '৷', 'সেগুলি', 'বেত', 'জাতীয়', 'লতা', 'দিয়ে', 'পরস্পর', 'বাঁধা', '৷', 'ঘরগুলি', 'লম্বায়', '18', 'ফুট', ',', 'চওড়ায়', '9', 'ফুট', 'আর', 'উচ্চতায়', '10'
# ...

# %%
#Stemming
from nltk.stem import LancasterStemmer
lancaster=LancasterStemmer()
print("Orignal Sentence:",str1)
print("\n")

str1 = [lancaster.stem(token) for token in str1.split(" ")]
print("Stemmed Sentence:")
print(" ".join(str1))
# Out:
# Orignal Sentence: মহিষের সন্তান : তোড়া উপজাতি ৷ বাসস্থান-ঘরগৃহস্থালি তোড়া ভাষায় গ্রামকেও বলে ` মোদ ' ৷ মোদের আয়তন খুব বড়ো নয় ৷ প্রতি মোদে আছে কিছু কুঁড়েঘর , সাধারণ মহিষশালা ৷ আর গ্রামের বাইরে থাকে ডেয়ারি-মন্দির ৷ আয়তনের তারতম্য অনুসারে গ্রামগুলি দু রকমের : এতূডমোদ ( বড়ো গ্রাম ) ওকিনমোদ ( ছোট গ্রাম ) ৷ কোন কোন গ্রামের আবার ধর্মীয় বা_C﻿মহিষের সন্তান : তোড়া উপজাতি ৷ িকে বলে ` সোতি-মোদ ' ৷ কুঁড়েঘরগুলির আকার বাংলার বা ভারতের অন্য অঞ্চলের প্রচলিত কুঁড়ে ঘর নয় ৷ এগুলি দেখতে শোয়ানো পিপের মতো ৷ এক দিকের বাঁশের কাঠামো খিলানের মতো বেঁকে গিয়ে অন্যদিকের মাটিতে মিশেছে ৷ সেগুলি বেত জাতীয় লতা দিয়ে পরস্পর বাঁধা ৷ ঘরগুলি লম্বায় 18 ফুট , চওড়ায় 9 ফুট আর উচ্চতায় 10 ফুটের মতো ৷ উপরের ঢালু চাল ঘাস-পাতা দিয়ে মোটা করে ছাওয়া ৷ যাতে বৃষ্টির জল ভেতরে ঢুকতে না পারে ৷ কুঁড়ের সামনের দিকে একটি মাত্র দরজা , আর কোথাও কোন রকমের জানলা বা ঘুলঘুলি নেই ৷ ঘরের ভেতরে ডানদিকের মেঝে কিছুটা উঁচু করে তোলা - সেটি তাদের শোবার জায়গা ৷ বাঁদিকে অগ্নিকুণ্ড - তার পাশে রান্না করার জায়গা ৷ সেখানেও মেঝে কিছুটা উঁচু - রান্নার সরঞ্জাম ও বাস
# ...
